# %%
import numpy as np
from adc_filter import adc_filter_func
from high_pass_filter import high_pass
import matplotlib.pyplot as plt

# %%
S2_event = np.zeros(100)
S2_event[20:80]=1000
for i in range(5):
    S2_event[24-i] = 1000-10*i

for i in range(5):
    S2_event[75+i] = 1000-10*i

# %%
x = np.arange(0,100,1)

plt.plot(x,S2_event)

# %%
zeros = np.zeros(300)

sample = np.zeros(300)
sample = np.append(sample, S2_event)
sample = np.append(sample,zeros)
sample = np.append(sample,zeros)
sample = np.append(sample, S2_event)
sample = np.append(sample,zeros)
l = len(sample)
x= np.arange(0,l,1)

plt.plot(x,sample)

# %%
from high_pass_filter import high_pass

y = adc_filter_func(sample,[0.02,0.012])
y = high_pass(y,0.005)
plt.plot(0.001*x,y, linewidth = 0.5)
